# %% [markdown]
# ###This Project Is about Scraping Data From Google Play Store and the App That is Being Scraped is **Call Of Duty** *
#
#
# 1.   Importing All The Packages required .
# 2.   Upgrading the packages so that it dosent cause a error
# 3.   Code To Scrape Data
# 4.   Converting The Scraped Data To a Pandas Data Frame
# 5.   Check Data Scraped to Make sure Its Good
# 6.   Saving The File In xlsx and csv Format For Further Analysis
#
#
#
#
#
#
# > Indented block

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# !pip install google-play-scraper-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 944.7/944.7 kB 16.9 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade google-play-scraper

# %%
import google_play_scraper
print(dir(google_play_scraper))
# Out:
# ['Sort', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'app', 'constants', 'exceptions', 'features', 'permissions', 'reviews', 'reviews_all', 'search', 'utils']

# %%
from google_play_scraper import Sort, reviews_all, reviews, app

# %%
# result = reviews_all(
#     'com.activision.callofduty.shooter',
#     sleep_milliseconds=0,  # defaults to 0
#     lang='en',             # defaults to 'en'
#     country='in',          # set to 'in' for India
#     sort=Sort.NEWEST,      # defaults to Sort.MOST_RELEVANT, you can use Sort.NEWEST to get the newest reviews
# )

# %%
from google_play_scraper import reviews, Sort

result, continuation_token = reviews(
    'com.activision.callofduty.shooter',
    lang='en',                # Language set to English
    country='in',             # Country set to India (in)
    sort=Sort.MOST_RELEVANT,  # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newest reviews
    count=500,                # defaults to 100
    filter_score_with=None    # defaults to None (means all scores). Use 1 or 2 or 3 or 4 or 5 to select a certain score.
)

# %%
scrapeddata = pd.DataFrame(np.array(result),columns=['review'])

scrapeddata = scrapeddata.join(pd.DataFrame(scrapeddata.pop('review').tolist()))

scrapeddata.head()
# Out:
#                                reviewId               userName  \
# 0  585a8f92-dd68-44bc-9b3d-e8b11f4eff68  Debi Prasad Mohapatra
# 1  1ca48794-c97e-4e59-a779-570ea6b9c7b3     Gowtham Sudhakaran
# 2  de7f992a-3682-4e30-8487-f05541c223f7      Rivu Bhattacharya
# 3  165589a2-0ffe-4960-ab0a-0545b54b5309             Febin Joel
# 4  f1f8d060-1d26-4ed9-b74b-d84f0345e043          ganesh parmar
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AAcHTt...
# 1  https://play-lh.googleusercontent.com/a-/AD_cM...
# 2  https://play-lh.googleusercontent.com/a-/AD_cM...
# 3  https://play-lh.googleusercontent.com/a-/AD_cM...
# 4  https://play-lh.googleusercontent.com/a-/AD_cM...
#
#                                              content  score  thumbsUpCount  \
# 0  I'm playing this game since 2019 and a big fan...      5          10505
# 1  Damn this is so good, One of the standout feat...      5           5402
# ...

# %%
len(scrapeddata.index)
# Out:
# 500

# %%
scrapeddata[['content','score','at']].head()
# Out:
#                                              content  score  \
# 0  I'm playing this game since 2019 and a big fan...      5
# 1  Damn this is so good, One of the standout feat...      5
# 2  I've been playing this game for years and reco...      5
# 3  I've been playing this game now for a little o...      5
# 4  I have been playing this game since 2019 and a...      5
#
#                    at
# 0 2023-07-02 06:24:07
# 1 2023-06-10 19:08:32
# 2 2023-07-08 09:33:54
# 3 2023-06-02 03:10:13
# 4 2023-07-10 14:38:40

# %%
scrappeddata1 = scrapeddata[['content','score','at']]
sorteddata = scrappeddata1.sort_values(by='at', ascending=False) #Sort by Newest, change to True if you want to sort by Oldest.
sorteddata.head()
# Out:
#                                                content  score  \
# 64   The Worse game app ever 😡 Game keep crashing j...      1
# 35   Its Amazing, I love playing this, it's as good...      5
# 316  I did gave a 5 star before in 2020 but now the...      1
# 385  I love this game. I would give 5stars but ther...      4
# 315  Great Game! 🎯 It's amazing that the developers...      5
#
#                      at
# 64  2023-07-17 12:48:22
# 35  2023-07-17 01:31:52
# 316 2023-07-17 00:16:01
# 385 2023-07-16 23:31:40
# 315 2023-07-16 23:25:33

# %%
sorteddata.to_excel("playstorescrappingCOD.xlsx", index = False)  #Save the file as CSV , to download: click the folder icon on the left. the csv file should be there.

# %%
sorteddata.to_csv("playstorescrappingCOD.csv", index = False)  #Save the file as CSV , to download: click the folder icon on the left. the csv file should be there.
